# %% [markdown]
# # Predictive Maintenance HVAC

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_parquet("hvac_data_cleaned.parquet")

# %% [markdown]
# ## Data Inspection

# %%
df.head()
# Out:
#             timestamp  on_off  damper  active_energy  co2_1  ambient_humidity  \
# 0 2022-06-01 00:00:00     0.0     0.0      762617.80  975.0              35.0
# 1 2022-06-01 00:05:00     0.0     0.0            NaN  977.0              35.0
# 2 2022-06-01 00:10:00     0.0     0.0            NaN  975.0              35.0
# 3 2022-06-01 00:15:00     0.0     0.0      762617.99  975.0              35.0
# 4 2022-06-01 00:20:00     0.0     0.0            NaN  975.0              35.0
#
#    active_power  power_generated  high_pressure_1  high_pressure_2  \
# 0          0.51              4.0            15.09             15.0
# 1          0.51              NaN            15.03             14.9
# 2          0.51              NaN            15.03             14.8
# 3          0.51              4.0            14.96             14.8
# 4          0.51              NaN            14.90             14.7
#
#    low_pressure_1  low_pressure_2  high_pressure_3  low_pressure_3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25632 entries, 0 to 25631
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         25632 non-null  datetime64[ns]
#  1   on_off            25557 non-null  float64
#  2   damper            25555 non-null  float64
#  3   active_energy     8518 non-null   float64
#  4   co2_1             25554 non-null  float64
#  5   ambient_humidity  25296 non-null  float64
#  6   active_power      25560 non-null  float64
#  7   power_generated   8544 non-null   float64
#  8   high_pressure_1   25553 non-null  float64
#  9   high_pressure_2   25556 non-null  float64
#  10  low_pressure_1    25553 non-null  float64
#  11  low_pressure_2    25556 non-null  float64
#  12  high_pressure_3   25556 non-null  float64
#  13  low_pressure_3    25556 non-null  float64
#  14  outside_temp      25555 non-null  float64
#  15  outlet_temp       25556 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'on_off', 'damper', 'active_energy', 'co2_1',
#        'ambient_humidity', 'active_power', 'power_generated',
#        'high_pressure_1', 'high_pressure_2', 'low_pressure_1',
#        'low_pressure_2', 'high_pressure_3', 'low_pressure_3', 'outside_temp',
#        'outlet_temp', 'inlet_temp', 'summer_SP_temp', 'winter_SP_temp',
#        'ambient_temp'],
#       dtype='object')

# %% [markdown]
# ## Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# timestamp               0
# on_off                 75
# damper                 77
# active_energy       17114
# co2_1                  78
# ambient_humidity      336
# active_power           72
# power_generated     17088
# high_pressure_1        79
# high_pressure_2        76
# low_pressure_1         79
# low_pressure_2         76
# high_pressure_3        76
# low_pressure_3         76
# outside_temp           77
# outlet_temp            76
# inlet_temp             75
# summer_SP_temp         76
# winter_SP_temp         77
# ambient_temp          142
# dtype: int64

# %%
df["timestamp"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.describe()
# Out:
#                            timestamp        on_off        damper  \
# count                          25632  25557.000000  25555.000000
# mean   2022-07-16 12:13:40.786516992      0.429002      8.311368
# min              2022-06-01 00:00:00      0.000000      0.000000
# 25%              2022-06-23 05:58:45      0.000000      0.000000
# 50%              2022-07-16 11:57:30      0.000000      0.000000
# 75%              2022-08-08 17:56:15      1.000000     13.000000
# max              2022-08-30 23:55:00      1.000000    100.000000
# std                              NaN      0.494943     16.820421
#
#        active_energy         co2_1  ambient_humidity  active_power  \
# count    8518.000000  25554.000000      25296.000000  25560.000000
# mean   794381.141334   1115.937387         39.317521     13.963495
# min    762617.800000    955.000000          0.000000      0.470000
# 25%    777009.267500   1025.000000         35.000000      0.510000
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# active_energy       17114
# power_generated     17088
# ambient_humidity      336
# ambient_temp          142
# high_pressure_1        79
# low_pressure_1         79
# co2_1                  78
# damper                 77
# outside_temp           77
# winter_SP_temp         77
# high_pressure_2        76
# low_pressure_2         76
# high_pressure_3        76
# low_pressure_3         76
# outlet_temp            76
# summer_SP_temp         76
# on_off                 75
# inlet_temp             75
# active_power           72
# timestamp               0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# timestamp            0.000000
# on_off               0.292603
# damper               0.300406
# active_energy       66.768102
# co2_1                0.304307
# ambient_humidity     1.310861
# active_power         0.280899
# power_generated     66.666667
# high_pressure_1      0.308208
# high_pressure_2      0.296504
# low_pressure_1       0.308208
# low_pressure_2       0.296504
# high_pressure_3      0.296504
# low_pressure_3       0.296504
# outside_temp         0.300406
# outlet_temp          0.296504
# inlet_temp           0.292603
# summer_SP_temp       0.296504
# winter_SP_temp       0.300406
# ambient_temp         0.553995
# dtype: float64

# %% [markdown]
# ## Dropping Highly Missing Columns

# %%
df.drop(columns=["active_energy", "power_generated"], inplace=True)

# %%
df.columns
# Out:
# Index(['timestamp', 'on_off', 'damper', 'co2_1', 'ambient_humidity',
#        'active_power', 'high_pressure_1', 'high_pressure_2', 'low_pressure_1',
#        'low_pressure_2', 'high_pressure_3', 'low_pressure_3', 'outside_temp',
#        'outlet_temp', 'inlet_temp', 'summer_SP_temp', 'winter_SP_temp',
#        'ambient_temp'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# ambient_humidity    336
# ambient_temp        142
# high_pressure_1      79
# low_pressure_1       79
# co2_1                78
# damper               77
# winter_SP_temp       77
# outside_temp         77
# low_pressure_3       76
# summer_SP_temp       76
# outlet_temp          76
# low_pressure_2       76
# high_pressure_3      76
# high_pressure_2      76
# on_off               75
# inlet_temp           75
# active_power         72
# timestamp             0
# dtype: int64

# %% [markdown]
# ## Filling Remaining Missing Values

# %%
df = df.fillna(df.mean(numeric_only=True))

# %% [markdown]
# ## Cleaned Dataset Overview

# %%
df.isnull().sum()
# Out:
# timestamp               0
# on_off                 75
# damper                 77
# active_energy       17114
# co2_1                  78
# ambient_humidity      336
# active_power           72
# power_generated     17088
# high_pressure_1        79
# high_pressure_2        76
# low_pressure_1         79
# low_pressure_2         76
# high_pressure_3        76
# low_pressure_3         76
# outside_temp           77
# outlet_temp            76
# inlet_temp             75
# summer_SP_temp         76
# winter_SP_temp         77
# ambient_temp          142
# dtype: int64

# %% [markdown]
# ## Exporting Cleaned Dataset

# %%
df.to_csv("cleaned_hvac_dataset.csv", index=False)

# %% [markdown]
# ## Conclusion
#
# - Cleaned and preprocessed the HVAC dataset.
# - Removed highly missing columns and handled remaining missing values.
# - Verified datetime formatting for time-based analysis.
# - Exported a cleaned dataset for future predictive maintenance analysis.
